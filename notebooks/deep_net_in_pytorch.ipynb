# %% [markdown]
# <a href="https://colab.research.google.com/github/jonkrohn/pytorch/blob/master/notebooks/deep_net_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Neural Network in PyTorch
#
# In this notebook, we adapt our [TensorFlow Deep Net](https://github.com/jonkrohn/DLTFpT/blob/master/notebooks/deep_net_in_tensorflow.ipynb) to PyTorch.

# %% [markdown]
# #### Load dependencies

# %%
import torch
import torch.nn as nn

from torchvision.datasets import MNIST
from torchvision import transforms

from torchsummary import summary

# %% [markdown]
# #### Load data

# %%
train = MNIST('data', train=True, transform=transforms.ToTensor(), download=True)
test = MNIST('data', train=False, transform=transforms.ToTensor())

# %% [markdown]
# #### Batch data

# %%
train_loader = torch.utils.data.DataLoader(train, batch_size=128) 
test_loader = torch.utils.data.DataLoader(test, batch_size=128)

# %% [markdown]
# #### Design neural network architecture

# %%
n_input = 784
n_dense_1 = 64
n_dense_2 = 64
n_dense_3 = 64
n_out = 10

# %%
model = nn.Sequential(
    
    # first hidden layer: 
    nn.Linear(n_input, n_dense_1), 
    nn.ReLU(), 
    
    # second hidden layer: 
    nn.Linear(n_dense_1, n_dense_2), 
    nn.ReLU(), 
    
    # third hidden layer: 
    nn.Linear(n_dense_2, n_dense_3), 
    nn.ReLU(), 
    nn.Dropout(),  
    
    # output layer: 
    nn.Linear(n_dense_3, n_out) 
)

# %%
summary(model, (1, n_input))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                [-1, 1, 64]          50,240
#               ReLU-2                [-1, 1, 64]               0
#             Linear-3                [-1, 1, 64]           4,160
#               ReLU-4                [-1, 1, 64]               0
#             Linear-5                [-1, 1, 64]           4,160
#               ReLU-6                [-1, 1, 64]               0
#            Dropout-7                [-1, 1, 64]               0
#             Linear-8                [-1, 1, 10]             650
# ================================================================
# Total params: 59,210
# Trainable params: 59,210
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.23
# Estimated Total Size (MB): 0.23
# ----------------------------------------------------------------

# %% [markdown]
# #### Configure training hyperparameters

# %%
cost_fxn = nn.CrossEntropyLoss() # includes softmax activation

# %%
optimizer = torch.optim.Adam(model.parameters())

# %% [markdown]
# #### Train

# %%
def accuracy_pct(pred_y, true_y):
  _, prediction = torch.max(pred_y, 1) # returns maximum values, indices; fed tensor, dim to reduce
  correct = (prediction == true_y).sum().item()
  return (correct / true_y.shape[0]) * 100.0

# %%
n_batches = len(train_loader)
n_batches
# Out:
# 469

# %%
n_epochs = 10 

print('Training for {} epochs. \n'.format(n_epochs))

for epoch in range(n_epochs):
  
  avg_cost = 0.0
  avg_accuracy = 0.0
  
  for i, (X, y) in enumerate(train_loader): # enumerate() provides count of iterations  
    
    # forward propagation:
    X_flat = X.view(X.shape[0], -1)
    y_hat = model(X_flat)
    cost = cost_fxn(y_hat, y)
    avg_cost += cost / n_batches
    
    # backprop and optimization via gradient descent: 
    optimizer.zero_grad() # set gradients to zero; .backward() accumulates them in buffers
    cost.backward()
    optimizer.step()
    
    # calculate accuracy metric:
    accuracy = accuracy_pct(y_hat, y)
    avg_accuracy += accuracy / n_batches
    
    if (i + 1) % 100 == 0:
      print('Step {}'.format(i + 1))
    
  print('Epoch {}/{} complete: Cost: {:.3f}, Accuracy: {:.1f}% \n'
        .format(epoch + 1, n_epochs, avg_cost, avg_accuracy)) 

print('Training complete.')
# Out:
# Training for 10 epochs.
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 1/10 complete: Cost: 0.674, Accuracy: 79.7%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 2/10 complete: Cost: 0.285, Accuracy: 92.2%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 3/10 complete: Cost: 0.211, Accuracy: 94.4%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 4/10 complete: Cost: 0.176, Accuracy: 95.3%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 5/10 complete: Cost: 0.147, Accuracy: 96.0%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 6/10 complete: Cost: 0.127, Accuracy: 96.6%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 7/10 complete: Cost: 0.114, Accuracy: 96.9%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 8/10 complete: Cost: 0.098, Accuracy: 97.3%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 9/10 complete: Cost: 0.088, Accuracy: 97.6%
#
# Step 100
# Step 200
# Step 300
# Step 400
# Epoch 10/10 complete: Cost: 0.077, Accuracy: 97.8%
#
# Training complete.

# %% [markdown]
# #### Test model

# %%
n_test_batches = len(test_loader)
n_test_batches
# Out:
# 79

# %%
model.eval() # disables dropout and batch norm

with torch.no_grad(): # disables autograd, reducing memory consumption
  
  avg_test_cost = 0.0
  avg_test_acc = 0.0
  
  for X, y in test_loader:
    
    # make predictions: 
    X_flat = X.view(X.shape[0], -1)
    y_hat = model(X_flat)
    
    # calculate cost: 
    cost = cost_fxn(y_hat, y)
    avg_test_cost += cost / n_test_batches
    
    # calculate accuracy:
    test_accuracy = accuracy_pct(y_hat, y)
    avg_test_acc += test_accuracy / n_test_batches

print('Test cost: {:.3f}, Test accuracy: {:.1f}%'.format(avg_test_cost, avg_test_acc))

# model.train() # 'undoes' model.eval()
# Out:
# Test cost: 0.106, Test accuracy: 97.0%
